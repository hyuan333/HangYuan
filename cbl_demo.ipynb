# %%
import matplotlib.pyplot as plt

# %run cbl1.ipynb

# For jupyter notebook add the following line:
# %matplotlib inline
price = model.datacollector.get_model_vars_dataframe()
price.plot()
# Out:
# Time: 0 .
# It is now time 0 .
# my__prediction [] .
# realized_price 0 .
# myprediction [61, 31, 24, 95, 56, 17] .
# myprediction [42, 8, 94, 71, 45, 91] .
# Time: 1 .
# It is now time 1 .
# my__prediction [] .
# realized_price 58.57142857142857 .
# myprediction [28, 84, 92, 90, 78, 58] .
# Time: 2 .
# It is now time 2 .
# my__prediction [] .
# realized_price 71.11111111111111 .
# myprediction [59, 23, 66, 17, 71, 35] .
# Time: 3 .
# It is now time 3 .
# my__prediction [] .
# realized_price 45.873015873015866 .
# myprediction [17, 49, 50, 55, 26, 43] .
# Time: 4 .
# It is now time 4 .
# my__prediction [] .
# realized_price 40.95238095238095 .
# myprediction [94, 46, 75, 56, 88, 28] .
# Time: 5 .
# It is now time 5 .
# my__prediction [] .
# realized_price 64.28571428571428 .
# myprediction [51, 37, 62, 26, 17, 2] .
# Time: 6 .
# It is now time 6 .
# my__prediction [] .
# realized_price 33.80952380952381 .
# myprediction [98, 88, 31, 72, 36, 56] .
# Time: 7 .
# It is now time 7 .
# my__prediction [] .
# realized_price 63.33333333333333 .
# myprediction [35, 15, 71, 71, 14, 49] .
# Time: 8 .
# It is now time 8 .
# my__prediction [] .
# realized_price 43.33333333333333 .
# myprediction [85, 70, 38, 41, 37, 6] .
# Time: 9 .
# It is now time 9 .
# my__prediction [] .
# realized_price 46.82539682539682 .
# myprediction [44, 71, 98, 35, 81, 42] .
# Time: 10 .
# It is now time 10 .
# my__prediction [] .
# realized_price 61.746031746031754 .
# myprediction [20, 43, 66, 51, 65, 14] .
# Time: 11 .
# It is now time 11 .
# my__prediction [] .
# realized_price 43.96825396825396 .
# myprediction [61, 85, 35, 41, 83, 61] .
# Time: 12 .
# It is now time 12 .
# my__prediction [] .
# realized_price 60.95238095238095 .
# myprediction [53, 50, 72, 18, 72, 85] .
# Time: 13 .
# It is now time 13 .
# my__prediction [] .
# realized_price 58.41269841269841 .
# myprediction [70, 64, 81, 42, 49, 25] .
# Time: 14 .
# It is now time 14 .
# my__prediction [] .
# realized_price 55.39682539682539 .
# myprediction [40, 92, 83, 9, 92, 17] .
# Time: 15 .
# It is now time 15 .
# my__prediction [] .
# realized_price 55.71428571428571 .
# myprediction [24, 98, 28, 78, 31, 36] .
# Time: 16 .
# It is now time 16 .
# my__prediction [] .
# realized_price 49.68253968253968 .
# myprediction [38, 98, 27, 45, 0, 40] .
# Time: 17 .
# It is now time 17 .
# my__prediction [] .
# realized_price 42.22222222222222 .
# myprediction [82, 95, 11, 53, 32, 39] .
# Time: 18 .
# It is now time 18 .
# my__prediction [] .
# realized_price 52.38095238095238 .
# myprediction [19, 8, 30, 59, 40, 36] .
# Time: 19 .
# It is now time 19 .
# my__prediction [] .
# realized_price 33.33333333333333 .
# myprediction [95, 89, 5, 36, 34, 57] .
# Time: 20 .
# It is now time 20 .
# my__prediction [] .
# realized_price 53.01587301587301 .
# myprediction [60, 76, 99, 38, 38, 90] .
# Time: 21 .
# It is now time 21 .
# my__prediction [] .
# realized_price 66.5079365079365 .
# myprediction [41, 5, 98, 5, 27, 4] .
# Time: 22 .
# It is now time 22 .
# my__prediction [] .
# realized_price 31.428571428571427 .
# myprediction [47, 73, 39, 18, 79, 28] .
# Time: 23 .
# It is now time 23 .
# my__prediction [] .
# realized_price 47.93650793650794 .
# myprediction [73, 72, 33, 94, 11, 72] .
# Time: 24 .
# It is now time 24 .
# my__prediction [] .
# realized_price 59.2063492063492 .
# myprediction [58, 47, 31, 96, 11, 61] .
# Time: 25 .
# It is now time 25 .
# my__prediction [] .
# realized_price 51.11111111111111 .
# myprediction [69, 68, 5, 62, 35, 5] .
# Time: 26 .
# It is now time 26 .
# my__prediction [] .
# realized_price 41.58730158730158 .
# myprediction [93, 100, 69, 87, 41, 81] .
# Time: 27 .
# It is now time 27 .
# my__prediction [] .
# realized_price 77.61904761904762 .
# myprediction [28, 33, 28, 73, 47, 98] .
# Time: 28 .
# It is now time 28 .
# my__prediction [] .
# realized_price 51.58730158730158 .
# myprediction [57, 86, 71, 53, 75, 17] .
# Time: 29 .
# It is now time 29 .
# my__prediction [] .
# realized_price 59.84126984126984 .
# myprediction [98, 32, 85, 36, 38, 56] .
# Time: 30 .
# It is now time 30 .
# my__prediction [] .
# realized_price 57.61904761904761 .
# myprediction [93, 27, 32, 29, 63, 5] .
# Time: 31 .
# It is now time 31 .
# my__prediction [] .
# realized_price 42.38095238095238 .
# myprediction [94, 51, 86, 29, 8, 35] .
# Time: 32 .
# It is now time 32 .
# my__prediction [] .
# realized_price 50.95238095238095 .
# myprediction [51, 92, 0, 11, 23, 42] .
# Time: 33 .
# It is now time 33 .
# my__prediction [] .
# realized_price 37.61904761904762 .
# myprediction [7, 90, 88, 86, 6, 14] .
# Time: 34 .
# It is now time 34 .
# my__prediction [] .
# realized_price 49.047619047619044 .
# myprediction [32, 95, 8, 41, 70, 61] .
# Time: 35 .
# It is now time 35 .
# my__prediction [] .
# realized_price 51.58730158730158 .
# myprediction [54, 20, 64, 100, 95, 40] .
# Time: 36 .
# It is now time 36 .
# my__prediction [] .
# realized_price 62.06349206349205 .
# myprediction [48, 14, 3, 56, 52, 35] .
# Time: 37 .
# It is now time 37 .
# my__prediction [] .
# realized_price 35.873015873015866 .
# myprediction [78, 11, 0, 66, 50, 42] .
# Time: 38 .
# It is now time 38 .
# my__prediction [] .
# realized_price 42.063492063492056 .
# myprediction [79, 98, 19, 30, 18, 16] .
# Time: 39 .
# It is now time 39 .
# my__prediction [] .
# realized_price 44.12698412698413 .
# myprediction [39, 63, 65, 36, 28, 67] .
# Time: 40 .
# It is now time 40 .
# my__prediction [] .
# realized_price 50.15873015873015 .
# myprediction [23, 84, 65, 17, 76, 83] .
# Time: 41 .
# It is now time 41 .
# my__prediction [] .
# realized_price 58.095238095238095 .
# myprediction [0, 34, 28, 29, 52, 31] .
# Time: 42 .
# It is now time 42 .
# my__prediction [] .
# realized_price 30.476190476190474 .
# myprediction [90, 90, 85, 12, 61, 26] .
# Time: 43 .
# It is now time 43 .
# my__prediction [] .
# realized_price 60.63492063492063 .
# myprediction [56, 93, 14, 1, 39, 57] .
# Time: 44 .
# It is now time 44 .
# my__prediction [] .
# realized_price 44.12698412698413 .
# myprediction [95, 41, 0, 35, 78, 52] .
# Time: 45 .
# It is now time 45 .
# my__prediction [] .
# realized_price 50.63492063492063 .
# myprediction [99, 42, 32, 0, 53, 67] .
# Time: 46 .
# It is now time 46 .
# my__prediction [] .
# realized_price 49.36507936507937 .
# myprediction [53, 71, 55, 46, 10, 79] .
# Time: 47 .
# It is now time 47 .
# my__prediction [] .
# realized_price 52.698412698412696 .
# myprediction [64, 74, 88, 50, 63, 60] .
# Time: 48 .
# It is now time 48 .
# my__prediction [] .
# realized_price 66.19047619047619 .
# myprediction [81, 80, 83, 52, 1, 27] .
# Time: 49 .
# It is now time 49 .
# my__prediction [] .
# realized_price 54.285714285714285 .
# myprediction [74, 38, 61, 66, 16, 28] .
# Time: 50 .
# It is now time 50 .
# my__prediction [] .
# realized_price 47.77777777777777 .

# %%
import matplotlib.pyplot as plt

# For jupyter notebook add the following line:
# %matplotlib inline
price = model.datacollector.get_model_vars_dataframe()
price.plot()
