# %%
# %run cbl1.ipynb
# Out:
# Time: 0 .
# It is now time 0 .
# my__prediction [] .
# realized_price 0 .
# agents [<__main__.CaseAgent object at 0x00BB13D0>, <__main__.CaseAgent object at 0x00BB1410>, <__main__.CaseAgent object at 0x00BB1DD0>, <__main__.CaseAgent object at 0x00BB1FD0>, <__main__.CaseAgent object at 0x00BB1230>, <__main__.CaseAgent object at 0x00BB1B50>] .
# myprediction [64, 28, 27, 23, 10, 1] .
# myprediction [74, 68, 11, 78, 37, 74] .
# Time: 1 .
# It is now time 1 .
# my__prediction [] .
# realized_price 57.14285714285714 .
# agents [<__main__.CaseAgent object at 0x00BB12F0>, <__main__.CaseAgent object at 0x00BB1350>, <__main__.CaseAgent object at 0x00BB17F0>, <__main__.CaseAgent object at 0x00BB19D0>, <__main__.CaseAgent object at 0x00BB15D0>, <__main__.CaseAgent object at 0x00BB1A10>] .
# myprediction [9, 56, 36, 89, 6, 100] .
# Time: 2 .
# It is now time 2 .
# my__prediction [] .
# realized_price 49.84126984126984 .
# ...
