# %%
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.datacollection import DataCollector
from mesa.batchrunner import BatchRunner
import random
import math, statistics
import numpy as np
from scipy.spatial import distance

# %% [markdown]
# Agent

# %%
class CaseAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 0
        self.memory = []
        self.prediction = 1
        self.result=0
        self.cases = []
        self.circumstances = []
        self.action_set=np.linspace(0,99,100)
  
        
    def euclidean_distance(self,new,old):
        return math.sqrt(sum(pow(a-b,2) for a, b in zip(new,old)))
       
    #def similarity(self):
        #return 1/math.exp(self.euclidean_distance(self.get_new,self.get_old))
    
      

    def get_new(self):
        for action in self.action_set:
            new = np.array(action,self.get_circumstance)
            return new
        
    def get_old(self):
        for case in self.cases:
            old = np.array(cases["action"], cases["circumstance"])
        return old
        
    def get_circumstance(self):
        if len(model.realized_prices_list) <=2:
            new_circumstance = random.choice(np.linspace(0,99,100))
        else:
            new_circumstance = model.realized_prices_list[-2] - model.realized_prices_list[-1]
        return new_circumstance
        print( "new circumstance is", new_circumstance, ".")
    
    def make_prediction(self):
        if not self.cases:
            prediction = random.choice(self.action_set)
            
        else:
            best_choice = self.evaluate_actions()    
            prediction=random.choice(best_choice)
        return prediction    
         
    
    def evaluate_actions(self):                  #evaluate all the actions and choose the one which has highest CBU
        cbu_list = list()
        for action in self.action_set: #<--- for each action 
            all_action_cbu = []
            new = np.array([action,self.get_circumstance()])
            #print(new)
                    
            for case in self.cases: #<--- looping through memory for each action, accumulate data in all_action_cbu    
                old = np.array([case["action"], case["circumstance"]]) 
                
                if abs(new[0]-old[0]) >= model.B/2: #<--- do not consider this case, out of bandwidth
                    pass # you don't need to do anything here
                    
                else: #<--- consider this case and add to all_action_cbu
                    similarity =1/math.exp(distance.euclidean(new,old))
                    single_case_cbu = similarity*(case["result"] - model.H)
                    all_action_cbu.append(single_case_cbu)
             
            # Now, we have gone through all memory, and evaluate it for this action
            if len(all_action_cbu) == 0 : # I have found NO relevant cases in memory (TODO: CHECK CODE)
                cbu = 0
            else: # I have found at least one relevant case
                cbu = sum(all_action_cbu)

            act_value = {"action":action, "value":cbu}
            cbu_list.append(act_value)
            # now we have act_value for this action
        
        best_value = max(cbu_list, key=(lambda x: x["value"]))
        print("best_value is ",best_value)
        best_choices= []
        best_choices.append(best_value["action"])
      

        for act_value in cbu_list:
            if act_value["value"] == best_value["value"]:
                best_choices.append(act_value["action"])
                
        return best_choices
        print(best_choices,".")            
    
    def get_result(self):
        result = max(1/2*(1-(model.realized_price - self.prediction)**2/7),0)   #calculate each agent's payoff
        return result

# %% [markdown]
# Memory

# %% [markdown]
# Model

# %%
class CaseModel(Model):
    """A model with some number of agents."""
    def __init__(self, N, Bandwidth, H):
        self.num_agents = 6
        # Create agents
        self.schedule = RandomActivation(self)
        self.predictions=[]
        self.results=[]
        self.wealths=[]
        self.realized_price = 0
        self.realized_prices_list = []
        self.agents=[] #ADP: have an agents vector directly in Model.
        self.tick=0    #ADP: keep track of time.
        self.H = H
        self.B = Bandwidth
          # Create agents
        for i in range(self.num_agents):
            a = CaseAgent(i, self)
            self.schedule.add(a)
            self.agents.append(a)
        self.datacollector = DataCollector(
            model_reporters={"Price": "realized_price"},
            agent_reporters={"Wealth": "wealth", "Result": "result", "Action": "prediction", "Cases":"cases"})
        
    def reset(self):
        self.predictions = []
        self.results = []
    def calculate_price(self):
        realized_price = round(20/21*(statistics.mean(self.predictions)+3))
        return realized_price
    def update_H(self):
        self.H = (self.H)**0.95
        return self.H
    def step(self):
        '''Advance the model by one step.'''
        self.schedule.step()
        self.tick += 1 # ADP: iterate time.
        previous_price = self.realized_price
        for i in self.agents:
            model.H = model.update_H()
            i.new_circumstance = i.get_circumstance()  #observe new circumstance
            
            print( "new circumstance:", i.new_circumstance, ".") 
            
            
            i.prediction = i.make_prediction()
            #print( "choices:", i.evaluate_actions, ".") 
            #agents make predictions for each round "action"
           
            model.predictions.append(i.prediction)
            
        self.realized_price = self.calculate_price()    #model calculate the market price  "circumstance" 
        model.realized_prices_list.append(self.realized_price)
        print("all past prices are:", model.realized_prices_list)
        
        for i in self.agents: 
            i.result = i.get_result()                 #agents get their payoff for each round  "result"
            model.results.append(i.result)
            
            i.new_case = {"action": i.prediction,
                        "result": i.result,
                        "circumstance": i.get_circumstance()}
            i.cases.append(i.new_case)
            print(i.cases[:3]) 
      
           
            #i.actions_chosen.append(i.prediction)
            i.wealth = i.wealth + i.result             #cumulative wealth
           # i.memory = i.memory.add_memory()
        self.datacollector.collect(self)    
       
        
       
        print( "Time:", self.tick, ".") 
        print( "Model_predictions:", self.predictions, ".")  
        print( "Model_results:", self.results, ".")
      
       
        self.reset() 
    def print(self): 
        # ADP: Give every object a "print" function.
     
        #print( "my__prediction", self.predictions, ".")
        print( "realized_price", self.realized_price, ".")

# %% [markdown]
# Run the model

# %%
model = CaseModel(50,10,0.5)
for i in range(50):
    
    model.step()
    #model.print()
# Out:
# new circumstance: 90.0 .
# new circumstance: 10.0 .
# new circumstance: 53.0 .
# new circumstance: 97.0 .
# new circumstance: 15.0 .
# new circumstance: 60.0 .
# all past prices are: [33.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}]
# Time: 1 .
# Model_predictions: [16.0, 34.0, 89.0, 30.0, 17.0, 2.0] .
# Model_results: [0, 0.4285714285714286, 0, 0, 0, 0] .
# new circumstance: 26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 71.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 55.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 93.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 36.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 20.0 .
# best_value is  {'action': 7.0, 'value': 0}
# all past prices are: [33.0, 60.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}]
# Time: 2 .
# Model_predictions: [82.0, 50.0, 80.0, 96.0, 38.0, 11.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 0.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 60.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 83.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 78.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 3 .
# Model_predictions: [18.0, 16.0, 8.0, 41.0, 0.0, 37.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 38.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 4 .
# Model_predictions: [88.0, 37.0, 60.0, 19.0, 23.0, 60.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -26.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 5 .
# Model_predictions: [10.0, 89.0, 21.0, 33.0, 11.0, 81.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 6 .
# Model_predictions: [47.0, 50.0, 44.0, 54.0, 61.0, 21.0] .
# Model_results: [0.5, 0, 0, 0, 0, 0] .
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 7 .
# Model_predictions: [76.0, 76.0, 53.0, 48.0, 71.0, 72.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 8 .
# Model_predictions: [74.0, 79.0, 38.0, 78.0, 83.0, 92.0] .
# Model_results: [0.4285714285714286, 0, 0, 0, 0, 0] .
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -7.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 9 .
# Model_predictions: [37.0, 0.0, 86.0, 69.0, 89.0, 83.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 12.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 10 .
# Model_predictions: [81.0, 15.0, 73.0, 63.0, 19.0, 59.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 11 .
# Model_predictions: [85.0, 44.0, 94.0, 37.0, 65.0, 53.0] .
# Model_results: [0, 0, 0, 0, 0.2142857142857143, 0] .
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 12 .
# Model_predictions: [8.0, 80.0, 24.0, 95.0, 24.0, 5.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 23.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 13 .
# Model_predictions: [30.0, 9.0, 73.0, 21.0, 43.0, 65.0] .
# Model_results: [0, 0, 0, 0, 0.2142857142857143, 0] .
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 14 .
# Model_predictions: [75.0, 66.0, 82.0, 68.0, 91.0, 50.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -30.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 15 .
# Model_predictions: [53.0, 46.0, 69.0, 45.0, 46.0, 48.0] .
# Model_results: [0.4285714285714286, 0, 0, 0, 0, 0] .
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 19.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 16 .
# Model_predictions: [15.0, 26.0, 14.0, 71.0, 59.0, 75.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 8.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 17 .
# Model_predictions: [95.0, 71.0, 32.0, 30.0, 24.0, 66.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -9.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 18 .
# Model_predictions: [35.0, 56.0, 38.0, 3.0, 75.0, 21.0] .
# Model_results: [0, 0, 0.4285714285714286, 0, 0, 0] .
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 19 .
# Model_predictions: [7.0, 72.0, 97.0, 40.0, 16.0, 32.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -6.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 20 .
# Model_predictions: [2.0, 42.0, 79.0, 94.0, 65.0, 49.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 21 .
# Model_predictions: [88.0, 74.0, 43.0, 3.0, 38.0, 2.0] .
# Model_results: [0, 0, 0.4285714285714286, 0, 0, 0] .
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 13.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 22 .
# Model_predictions: [26.0, 15.0, 44.0, 94.0, 83.0, 83.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 23 .
# Model_predictions: [36.0, 92.0, 49.0, 69.0, 50.0, 78.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -4.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 24 .
# Model_predictions: [39.0, 33.0, 65.0, 77.0, 51.0, 78.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 25 .
# Model_predictions: [25.0, 54.0, 76.0, 84.0, 28.0, 13.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 26 .
# Model_predictions: [69.0, 54.0, 94.0, 75.0, 51.0, 64.0] .
# Model_results: [0.2142857142857143, 0, 0, 0, 0, 0] .
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -20.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 27 .
# Model_predictions: [96.0, 31.0, 58.0, 39.0, 82.0, 91.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 28 .
# Model_predictions: [52.0, 35.0, 99.0, 94.0, 49.0, 53.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 3.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 29 .
# Model_predictions: [80.0, 6.0, 89.0, 75.0, 74.0, 25.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 30 .
# Model_predictions: [96.0, 26.0, 44.0, 99.0, 26.0, 52.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 1.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# ...
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 38 .
# Model_predictions: [49.0, 59.0, 10.0, 43.0, 12.0, 70.0] .
# Model_results: [0, 0, 0, 0.2142857142857143, 0, 0] .
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 24.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 39 .
# Model_predictions: [31.0, 43.0, 22.0, 91.0, 50.0, 89.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -14.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 40 .
# Model_predictions: [87.0, 12.0, 94.0, 84.0, 14.0, 4.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 5.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 41 .
# Model_predictions: [78.0, 61.0, 54.0, 89.0, 76.0, 38.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0, 50.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 42 .
# Model_predictions: [48.0, 68.0, 12.0, 41.0, 54.0, 77.0] .
# Model_results: [0.2142857142857143, 0, 0, 0, 0, 0] .
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 16.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0, 50.0, 40.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 43 .
# Model_predictions: [32.0, 50.0, 75.0, 62.0, 8.0, 5.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 10.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0, 50.0, 40.0, 58.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 44 .
# Model_predictions: [82.0, 94.0, 19.0, 88.0, 19.0, 43.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -18.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0, 50.0, 40.0, 58.0, 36.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 45 .
# Model_predictions: [22.0, 49.0, 47.0, 49.0, 24.0, 20.0] .
# Model_results: [0, 0, 0, 0, 0, 0] .
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: 22.0 .
# best_value is  {'action': 0.0, 'value': 0}
# all past prices are: [33.0, 60.0, 22.0, 48.0, 42.0, 47.0, 66.0, 73.0, 61.0, 52.0, 63.0, 40.0, 41.0, 71.0, 52.0, 44.0, 53.0, 39.0, 45.0, 55.0, 42.0, 58.0, 62.0, 57.0, 47.0, 67.0, 66.0, 63.0, 58.0, 57.0, 39.0, 38.0, 60.0, 48.0, 55.0, 49.0, 65.0, 41.0, 55.0, 50.0, 66.0, 50.0, 40.0, 58.0, 36.0, 47.0]
# [{'action': 16.0, 'result': 0, 'circumstance': 32.0}, {'action': 82.0, 'result': 0, 'circumstance': 39.0}, {'action': 18.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 34.0, 'result': 0.4285714285714286, 'circumstance': 31.0}, {'action': 50.0, 'result': 0, 'circumstance': 22.0}, {'action': 16.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 89.0, 'result': 0, 'circumstance': 43.0}, {'action': 80.0, 'result': 0, 'circumstance': 3.0}, {'action': 8.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 30.0, 'result': 0, 'circumstance': 78.0}, {'action': 96.0, 'result': 0, 'circumstance': 41.0}, {'action': 41.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 17.0, 'result': 0, 'circumstance': 20.0}, {'action': 38.0, 'result': 0, 'circumstance': 21.0}, {'action': 0.0, 'result': 0, 'circumstance': 38.0}]
# [{'action': 2.0, 'result': 0, 'circumstance': 61.0}, {'action': 11.0, 'result': 0, 'circumstance': 99.0}, {'action': 37.0, 'result': 0, 'circumstance': 38.0}]
# Time: 46 .
# Model_predictions: [19.0, 71.0, 49.0, 86.0, 29.0, 23.0] .
# Model_results: [0, 0, 0.2142857142857143, 0, 0, 0] .
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance: -11.0 .
# best_value is  {'action': 0.0, 'value': 0}
# new circumstance:
